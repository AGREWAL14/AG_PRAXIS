# %% [markdown]
# # AG_PRAXIS NB01 — Load and Inventory the CICIoMT2024 CSVs
#
# Before I decide anything about models, windows, or splits, I need to know what is
# actually in these files. The dataset paper describes the features, but I want to read
# the columns myself rather than take the description on trust.
#
# This notebook answers the questions I cannot proceed without. What are the columns and
# what type is each one. Is there a timestamp anywhere. Is there anything that identifies
# a sender or a receiver. Is the schema the same in every file or only in most of them.
# How many rows are there per file and per attack family.
#
# It writes two files. `data/processed/schema.json` records the column list, the dtypes,
# and the answers to the timestamp and endpoint questions, so that no later notebook has
# to guess at them. `config/feature_families.yaml` is a first grouping of the columns,
# written as a draft because it is derived from spelling alone. Nothing is trained here.

# %% [markdown]
# The data sits on Drive and the code sits in the repository, so the first block mounts
# one and clones the other. It also records the commit it is running from. Every number
# printed below belongs to that commit, and if the working tree is dirty I would rather
# see it now than when I am trying to explain a result later.

# %%
import os
import subprocess
import sys
from datetime import date
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/AGREWAL14/AG_PRAXIS.git"

if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/drive")
    REPO_ROOT = Path("/content/repo")
    if REPO_ROOT.exists():
        subprocess.run(["git", "-C", str(REPO_ROOT), "pull", "--ff-only"], check=True)
    else:
        subprocess.run(["git", "clone", REPO_URL, str(REPO_ROOT)], check=True)
else:
    REPO_ROOT = Path.cwd()
    while not (REPO_ROOT / "config" / "base.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
        REPO_ROOT = REPO_ROOT.parent

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))


def git(*args):
    return subprocess.run(
        ["git", "-C", str(REPO_ROOT), *args], capture_output=True, text=True
    ).stdout.strip()


GIT_SHA = git("rev-parse", "--short", "HEAD")
GIT_BRANCH = git("rev-parse", "--abbrev-ref", "HEAD")
GIT_DIRTY = bool(git("status", "--porcelain"))
RUN_DATE = date.today().isoformat()

print(f"colab     : {IN_COLAB}")
print(f"repo root : {REPO_ROOT}")
print(f"git sha   : {GIT_SHA} on {GIT_BRANCH}" + ("   WORKING TREE DIRTY" if GIT_DIRTY else ""))
print(f"run date  : {RUN_DATE}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# colab     : True
# repo root : /content/repo
# git sha   : d3f634b on main
# run date  : 2026-08-02

# %% [markdown]
# Paths and the seed come from `config/base.yaml` rather than from anything typed into a
# cell, so that changing a path is a commit and not an edit I forget I made. `FAST` is on
# by default. In this notebook it controls one thing only: how many files are read in
# full for the dtype comparison. The cheap checks, which are the column names and the row
# counts, run over every file either way.

# %%
import json
import random

import numpy as np
import pandas as pd

from src import inventory as inv

CFG = inv.load_config(REPO_ROOT)

SEED = CFG["seed"]
TRAIN_DIR = Path(CFG["paths"]["train_dir"])
TEST_DIR = Path(CFG["paths"]["test_dir"])
ARTIFACTS = Path(CFG["paths"]["artifacts"])

FAST = os.environ.get("FAST", "1") == "1"
FAST_FILE_LIMIT = 8

pd.set_option("display.max_rows", 250)
pd.set_option("display.width", 170)

print(f"seed      : {SEED}")
print(f"train dir : {TRAIN_DIR}   exists={TRAIN_DIR.exists()}")
print(f"test dir  : {TEST_DIR}   exists={TEST_DIR.exists()}")
print(f"artifacts : {ARTIFACTS}   exists={ARTIFACTS.exists()}")
print(f"FAST      : {int(FAST)}")
if FAST:
    print(f"            dtype check limited to the first {FAST_FILE_LIMIT} files")
    print("            a run entered in the ledger requires FAST=0")
# Out:
# seed      : 42
# train dir : /content/drive/MyDrive/AG_PRAXIS_data/csv/train   exists=True
# test dir  : /content/drive/MyDrive/AG_PRAXIS_data/csv/test   exists=True
# artifacts : /content/drive/MyDrive/AG_PRAXIS_artifacts   exists=True
# FAST      : 1
#             dtype check limited to the first 8 files
#             a run entered in the ledger requires FAST=0

# %% [markdown]
# No model is built here, but the seed is set before anything else runs so that any
# sampling I do while looking at the data gives the same rows the next time.

# %%
random.seed(SEED)
np.random.seed(SEED)
print(f"seeded with {SEED}")
# Out:
# seeded with 42

# %% [markdown]
# First the files themselves. The class a file holds and the family it belongs to are both
# readable from its name, so I derive them here and print the whole mapping. If the
# derivation is wrong I would rather see it on one screen now than find it later inside a
# count that does not add up.

# %%
train_files = inv.list_csvs(TRAIN_DIR)
test_files = inv.list_csvs(TEST_DIR)
ALL_FILES = train_files + test_files
EXPECTED_FILES = 72

files = pd.DataFrame(
    {
        "file": [p.name for p in ALL_FILES],
        "split": [inv.split_name(p) for p in ALL_FILES],
        "class": [inv.class_name(p) for p in ALL_FILES],
        "family": [inv.family_name(p) for p in ALL_FILES],
    }
)

print(f"train files : {len(train_files)}")
print(f"test files  : {len(test_files)}")
print(f"total       : {len(ALL_FILES)}   (expected {EXPECTED_FILES})")
if len(ALL_FILES) != EXPECTED_FILES:
    print(f"MISMATCH: found {len(ALL_FILES)}, not {EXPECTED_FILES}. Check the paths printed above.")
print()
print(files.to_string(index=False))
print()
print(f"distinct classes  : {files['class'].nunique()}")
print(f"distinct families : {files['family'].nunique()}")
print()
print(files.groupby("family").size().sort_values(ascending=False).to_string())
# Out:
# train files : 51
# test files  : 21
# total       : 72   (expected 72)
#
#                                   file split                   class       family
#            ARP_Spoofing_train.pcap.csv train            ARP_Spoofing ARP_Spoofing
#                  Benign_train.pcap.csv train                  Benign       Benign
# MQTT-DDoS-Connect_Flood_train.pcap.csv train MQTT-DDoS-Connect_Flood         MQTT
# MQTT-DDoS-Publish_Flood_train.pcap.csv train MQTT-DDoS-Publish_Flood         MQTT
#  MQTT-DoS-Connect_Flood_train.pcap.csv train  MQTT-DoS-Connect_Flood         MQTT
#  MQTT-DoS-Publish_Flood_train.pcap.csv train  MQTT-DoS-Publish_Flood         MQTT
#     MQTT-Malformed_Data_train.pcap.csv train     MQTT-Malformed_Data         MQTT
#           Recon-OS_Scan_train.pcap.csv train           Recon-OS_Scan        Recon
#        Recon-Ping_Sweep_train.pcap.csv train        Recon-Ping_Sweep        Recon
#         Recon-Port_Scan_train.pcap.csv train         Recon-Port_Scan        Recon
#           Recon-VulScan_train.pcap.csv train           Recon-VulScan        Recon
#       TCP_IP-DDoS-ICMP1_train.pcap.csv train       TCP_IP-DDoS-ICMP1       TCP_IP
#       TCP_IP-DDoS-ICMP2_train.pcap.csv train       TCP_IP-DDoS-ICMP2       TCP_IP
#       TCP_IP-DDoS-ICMP3_train.pcap.csv train       TCP_IP-DDoS-ICMP3       TCP_IP
#       TCP_IP-DDoS-ICMP4_train.pcap.csv train       TCP_IP-DDoS-ICMP4       TCP_IP
#       TCP_IP-DDoS-ICMP5_train.pcap.csv train       TCP_IP-DDoS-ICMP5       TCP_IP
#       TCP_IP-DDoS-ICMP6_train.pcap.csv train       TCP_IP-DDoS-ICMP6       TCP_IP
#       TCP_IP-DDoS-ICMP7_train.pcap.csv train       TCP_IP-DDoS-ICMP7       TCP_IP
#       TCP_IP-DDoS-ICMP8_train.pcap.csv train       TCP_IP-DDoS-ICMP8       TCP_IP
#        TCP_IP-DDoS-SYN1_train.pcap.csv train        TCP_IP-DDoS-SYN1       TCP_IP
#        TCP_IP-DDoS-SYN2_train.pcap.csv train        TCP_IP-DDoS-SYN2       TCP_IP
#        TCP_IP-DDoS-SYN3_train.pcap.csv train        TCP_IP-DDoS-SYN3       TCP_IP
#        TCP_IP-DDoS-SYN4_train.pcap.csv train        TCP_IP-DDoS-SYN4       TCP_IP
#        TCP_IP-DDoS-TCP1_train.pcap.csv train        TCP_IP-DDoS-TCP1       TCP_IP
#        TCP_IP-DDoS-TCP2_train.pcap.csv train        TCP_IP-DDoS-TCP2       TCP_IP
#        TCP_IP-DDoS-TCP3_train.pcap.csv train        TCP_IP-DDoS-TCP3       TCP_IP
#        TCP_IP-DDoS-TCP4_train.pcap.csv train        TCP_IP-DDoS-TCP4       TCP_IP
#        TCP_IP-DDoS-UDP1_train.pcap.csv train        TCP_IP-DDoS-UDP1       TCP_IP
#        TCP_IP-DDoS-UDP2_train.pcap.csv train        TCP_IP-DDoS-UDP2       TCP_IP
#        TCP_IP-DDoS-UDP3_train.pcap.csv train        TCP_IP-DDoS-UDP3       TCP_IP
#        TCP_IP-DDoS-UDP4_train.pcap.csv train        TCP_IP-DDoS-UDP4       TCP_IP
#        TCP_IP-DDoS-UDP5_train.pcap.csv train        TCP_IP-DDoS-UDP5       TCP_IP
#        TCP_IP-DDoS-UDP6_train.pcap.csv train        TCP_IP-DDoS-UDP6       TCP_IP
#        TCP_IP-DDoS-UDP7_train.pcap.csv train        TCP_IP-DDoS-UDP7       TCP_IP
#        TCP_IP-DDoS-UDP8_train.pcap.csv train        TCP_IP-DDoS-UDP8       TCP_IP
#        TCP_IP-DoS-ICMP1_train.pcap.csv train        TCP_IP-DoS-ICMP1       TCP_IP
#        TCP_IP-DoS-ICMP2_train.pcap.csv train        TCP_IP-DoS-ICMP2       TCP_IP
#        TCP_IP-DoS-ICMP3_train.pcap.csv train        TCP_IP-DoS-ICMP3       TCP_IP
#        TCP_IP-DoS-ICMP4_train.pcap.csv train        TCP_IP-DoS-ICMP4       TCP_IP
#         TCP_IP-DoS-SYN1_train.pcap.csv train         TCP_IP-DoS-SYN1       TCP_IP
#         TCP_IP-DoS-SYN2_train.pcap.csv train         TCP_IP-DoS-SYN2       TCP_IP
#         TCP_IP-DoS-SYN3_train.pcap.csv train         TCP_IP-DoS-SYN3       TCP_IP
#         TCP_IP-DoS-SYN4_train.pcap.csv train         TCP_IP-DoS-SYN4       TCP_IP
#         TCP_IP-DoS-TCP1_train.pcap.csv train         TCP_IP-DoS-TCP1       TCP_IP
#         TCP_IP-DoS-TCP2_train.pcap.csv train         TCP_IP-DoS-TCP2       TCP_IP
#         TCP_IP-DoS-TCP3_train.pcap.csv train         TCP_IP-DoS-TCP3       TCP_IP
#         TCP_IP-DoS-TCP4_train.pcap.csv train         TCP_IP-DoS-TCP4       TCP_IP
#         TCP_IP-DoS-UDP1_train.pcap.csv train         TCP_IP-DoS-UDP1       TCP_IP
#         TCP_IP-DoS-UDP2_train.pcap.csv train         TCP_IP-DoS-UDP2       TCP_IP
#         TCP_IP-DoS-UDP3_train.pcap.csv train         TCP_IP-DoS-UDP3       TCP_IP
#         TCP_IP-DoS-UDP4_train.pcap.csv train         TCP_IP-DoS-UDP4       TCP_IP
#             ARP_Spoofing_test.pcap.csv  test            ARP_Spoofing ARP_Spoofing
#                   Benign_test.pcap.csv  test                  Benign       Benign
#  MQTT-DDoS-Connect_Flood_test.pcap.csv  test MQTT-DDoS-Connect_Flood         MQTT
#  MQTT-DDoS-Publish_Flood_test.pcap.csv  test MQTT-DDoS-Publish_Flood         MQTT
#   MQTT-DoS-Connect_Flood_test.pcap.csv  test  MQTT-DoS-Connect_Flood         MQTT
#   MQTT-DoS-Publish_Flood_test.pcap.csv  test  MQTT-DoS-Publish_Flood         MQTT
#      MQTT-Malformed_Data_test.pcap.csv  test     MQTT-Malformed_Data         MQTT
#            Recon-OS_Scan_test.pcap.csv  test           Recon-OS_Scan        Recon
#         Recon-Ping_Sweep_test.pcap.csv  test        Recon-Ping_Sweep        Recon
#          Recon-Port_Scan_test.pcap.csv  test         Recon-Port_Scan        Recon
#            Recon-VulScan_test.pcap.csv  test           Recon-VulScan        Recon
#        TCP_IP-DDoS-ICMP1_test.pcap.csv  test       TCP_IP-DDoS-ICMP1       TCP_IP
#        TCP_IP-DDoS-ICMP2_test.pcap.csv  test       TCP_IP-DDoS-ICMP2       TCP_IP
#          TCP_IP-DDoS-SYN_test.pcap.csv  test         TCP_IP-DDoS-SYN       TCP_IP
#          TCP_IP-DDoS-TCP_test.pcap.csv  test         TCP_IP-DDoS-TCP       TCP_IP
#         TCP_IP-DDoS-UDP1_test.pcap.csv  test        TCP_IP-DDoS-UDP1       TCP_IP
#         TCP_IP-DDoS-UDP2_test.pcap.csv  test        TCP_IP-DDoS-UDP2       TCP_IP
#          TCP_IP-DoS-ICMP_test.pcap.csv  test         TCP_IP-DoS-ICMP       TCP_IP
#           TCP_IP-DoS-SYN_test.pcap.csv  test          TCP_IP-DoS-SYN       TCP_IP
#           TCP_IP-DoS-TCP_test.pcap.csv  test          TCP_IP-DoS-TCP       TCP_IP
#           TCP_IP-DoS-UDP_test.pcap.csv  test          TCP_IP-DoS-UDP       TCP_IP
#
# distinct classes  : 57
# distinct families : 5
#
# family
# TCP_IP          50
# MQTT            10
# Recon            8
# ARP_Spoofing     2
# Benign           2

# %% [markdown]
# Now the schema. I read one training file in full and print every column with its type,
# how many nulls it has, how many distinct values it takes, and its range where it is
# numeric. The distinct count is the part I care about most. A column holding one value
# carries no information at all, and a column with as many distinct values as there are
# rows is an identifier rather than a measurement, which would be a problem of a
# different kind.

# %%
REFERENCE_FILE = train_files[0]
ref = pd.read_csv(REFERENCE_FILE)

print(f"reference file : {REFERENCE_FILE.name}")
print(f"shape          : {ref.shape[0]:,} rows x {ref.shape[1]} columns")
print()

schema_table = inv.describe_columns(ref)
print(schema_table.to_string(index=False))

constant_cols = schema_table.loc[schema_table["n_unique"] <= 1, "column"].tolist()
rowwise_unique = schema_table.loc[schema_table["n_unique"] == len(ref), "column"].tolist()
null_cols = schema_table.loc[schema_table["nulls"] > 0, "column"].tolist()

print()
print(f"single-valued columns   : {constant_cols or 'none'}")
print(f"unique-per-row columns  : {rowwise_unique or 'none'}")
print(f"columns with any nulls  : {null_cols or 'none'}")
# Out:
# reference file : ARP_Spoofing_train.pcap.csv
# shape          : 16,047 rows x 45 columns
#
#          column   dtype  nulls  n_unique        min          max
#   Header_Length float64      0     15786   0.000000 9.584402e+06
#   Protocol Type float64      0        79   0.000000 1.700000e+01
#        Duration float64      0       590   0.000000 2.500000e+02
#            Rate float64      0     15889   0.011909 1.531246e+05
#           Srate float64      0     15889   0.011909 1.531246e+05
#           Drate float64      0         1   0.000000 0.000000e+00
# fin_flag_number float64      0         6   0.000000 6.000000e-01
# syn_flag_number float64      0         6   0.000000 5.000000e-01
# rst_flag_number float64      0         4   0.000000 3.000000e-01
# psh_flag_number float64      0        12   0.000000 1.000000e+00
# ack_flag_number float64      0        12   0.000000 1.000000e+00
# ece_flag_number float64      0         1   0.000000 0.000000e+00
# cwr_flag_number float64      0         1   0.000000 0.000000e+00
#       ack_count float64      0        18   0.000000 2.000000e+00
#       syn_count float64      0        27   0.000000 3.000000e+00
#       fin_count float64      0        21   0.000000 2.500000e+00
#       rst_count float64      0      6138   0.000000 9.576500e+03
#            HTTP float64      0        11   0.000000 1.000000e+00
#           HTTPS float64      0        11   0.000000 1.000000e+00
#             DNS float64      0         7   0.000000 6.000000e-01
#          Telnet float64      0         1   0.000000 0.000000e+00
#            SMTP float64      0         1   0.000000 0.000000e+00
#             SSH float64      0         1   0.000000 0.000000e+00
#             IRC float64      0         1   0.000000 0.000000e+00
#             TCP float64      0        12   0.000000 1.000000e+00
#             UDP float64      0        12   0.000000 1.000000e+00
#            DHCP float64      0         3   0.000000 2.000000e-01
#             ARP float64      0        11   0.000000 1.000000e+00
#            ICMP float64      0         4   0.000000 4.000000e-01
#            IGMP float64      0         1   0.000000 0.000000e+00
#             IPv float64      0        11   0.000000 1.000000e+00
#             LLC float64      0        11   0.000000 1.000000e+00
#         Tot sum float64      0     10056 285.000000 2.315700e+04
#             Min float64      0      1843  42.000000 1.514000e+03
#             Max float64      0      3946  56.400000 1.514000e+03
#             AVG float64      0     11605  49.071905 1.514000e+03
#             Std float64      0     11570   0.000000 7.024992e+02
#        Tot size float64      0      4858  51.000000 1.514000e+03
#             IAT float64      0     15532   0.000000 1.694027e+08
#          Number float64      0         7   1.000000 1.450000e+01
#        Magnitue float64      0     11567   9.891717 5.502727e+01
#          Radius float64      0     11537   0.000000 9.919649e+02
#      Covariance float64      0     11547   0.000000 4.920972e+05
#        Variance float64      0        12   0.000000 1.000000e+00
#          Weight float64      0         8   1.000000 2.446000e+02
#
# single-valued columns   : ['Drate', 'ece_flag_number', 'cwr_flag_number', 'Telnet', 'SMTP', 'SSH', 'IRC', 'IGMP']
# unique-per-row columns  : none
# columns with any nulls  : none

# %% [markdown]
# The first question that changes what I can build is whether there is a clock in the
# data. I search the column names for time, timestamp, ts, date and epoch, and I do it two
# ways. A whole-word match is a real hit. A letters-anywhere match is not, because `ts`
# sits inside `Packets` and `ip` sits inside plenty of words, so those are listed
# separately instead of being counted as findings.

# %%
time_hits = inv.search_columns(ref.columns, inv.TIME_KEYWORDS)
HAS_TIMESTAMP = bool(time_hits["word_hits"])

print("searched", len(ref.columns), "column names for:", ", ".join(inv.TIME_KEYWORDS))
print()
for col, kws in time_hits["word_hits"].items():
    print(f"  whole word   : {col}   [{', '.join(kws)}]")
for col, kws in time_hits["substring_hits"].items():
    print(f"  letters only : {col}   [{', '.join(kws)}]   coincidence, not a field")
if not time_hits["word_hits"] and not time_hits["substring_hits"]:
    print("  nothing matched, on either reading")
print()
print("VERDICT   timestamp column present:", "YES" if HAS_TIMESTAMP else "NO")
# Out:
# searched 45 column names for: time, timestamp, ts, date, epoch
#
#   nothing matched, on either reading
#
# VERDICT   timestamp column present: NO

# %% [markdown]
# The second question is whether anything identifies an endpoint. Same search, different
# words: src, dst, ip, mac, addr, source, destination and port. This one decides whether
# records can be grouped into flows or into a communication graph at all, or whether the
# files are already reduced to per-record statistics with the addressing thrown away.

# %%
endpoint_hits = inv.search_columns(ref.columns, inv.ENDPOINT_KEYWORDS)
HAS_ENDPOINTS = bool(endpoint_hits["word_hits"])

print("searched", len(ref.columns), "column names for:", ", ".join(inv.ENDPOINT_KEYWORDS))
print()
for col, kws in endpoint_hits["word_hits"].items():
    print(f"  whole word   : {col}   [{', '.join(kws)}]")
for col, kws in endpoint_hits["substring_hits"].items():
    print(f"  letters only : {col}   [{', '.join(kws)}]   coincidence, not a field")
if not endpoint_hits["word_hits"] and not endpoint_hits["substring_hits"]:
    print("  nothing matched, on either reading")
print()
print("VERDICT   endpoint identifiers present:", "YES" if HAS_ENDPOINTS else "NO")
# Out:
# searched 45 column names for: src, dst, ip, mac, addr, source, destination, port
#
#   letters only : IPv   [ip]   coincidence, not a field
#
# VERDICT   endpoint identifiers present: NO

# %% [markdown]
# Those two answers together decide how a sequence can be built, so the next block spells
# that out rather than leaving me to remember it. This is also the check the decision log
# records as outstanding, where the choice between sequence modelling and graph modelling
# was left resting on whether endpoints exist.

# %%
print("What this means for ordering records into sequences")
print()

if HAS_TIMESTAMP:
    print("A clock exists. Records can be sorted by time, gaps between them are")
    print("measurable, and a window can be cut on elapsed time rather than on row")
    print("position. Sort order must then be set explicitly and never assumed.")
else:
    print("There is no clock. The only ordering available is the order the rows appear")
    print("in the file, which is the order the feature extractor wrote them. That order")
    print("carries meaning inside a file and none across files, so a window must never")
    print("span two files, and the row index must never be shuffled before windowing.")

print()

if HAS_ENDPOINTS:
    print("Endpoint identifiers exist. Records can be grouped per host or per flow")
    print("before windowing, and nodes and edges for a communication graph are available.")
    print("They are also the most obvious shortcut in the data, so any model that reads")
    print("them has to be checked for learning the address instead of the behaviour.")
else:
    print("Nothing identifies a sender or a receiver. Records cannot be grouped into")
    print("flows or per-host streams, and there are no nodes from which to build a")
    print("communication graph. A sequence here is a run of consecutive rows from one")
    print("capture file and nothing finer than that.")

print()

if not HAS_TIMESTAMP and not HAS_ENDPOINTS:
    print("Both answers are negative, which fixes the definition used from here on:")
    print(f"a sequence is {CFG['sequence']['window']} consecutive rows taken from a single file at stride "
          f"{CFG['sequence']['stride']},")
    print("never crossing a file boundary. Graph modelling is not available on these")
    print("columns, because there is nothing to make a node out of.")
# Out:
# What this means for ordering records into sequences
#
# There is no clock. The only ordering available is the order the rows appear
# in the file, which is the order the feature extractor wrote them. That order
# carries meaning inside a file and none across files, so a window must never
# span two files, and the row index must never be shuffled before windowing.
#
# Nothing identifies a sender or a receiver. Records cannot be grouped into
# flows or per-host streams, and there are no nodes from which to build a
# communication graph. A sequence here is a run of consecutive rows from one
# capture file and nothing finer than that.
#
# Both answers are negative, which fixes the definition used from here on:
# a sequence is 50 consecutive rows taken from a single file at stride 25,
# never crossing a file boundary. Graph modelling is not available on these
# columns, because there is nothing to make a node out of.

# %% [markdown]
# One file agreeing with itself proves nothing about the other seventy-one. Reading just
# the header costs almost nothing, so I read the header of every file and compare the
# column list against the reference exactly, order included. Any file that differs is
# printed with what it is missing and what it has extra.

# %%
REFERENCE_COLUMNS = list(ref.columns)
column_differences = []

for path in ALL_FILES:
    cols = inv.header_of(path)
    if cols == REFERENCE_COLUMNS:
        continue
    missing = [c for c in REFERENCE_COLUMNS if c not in cols]
    extra = [c for c in cols if c not in REFERENCE_COLUMNS]
    column_differences.append(
        {
            "file": path.name,
            "n_columns": len(cols),
            "missing": missing,
            "extra": extra,
            "same_columns_reordered": not missing and not extra,
        }
    )

SCHEMA_IDENTICAL = not column_differences

print(f"reference : {REFERENCE_FILE.name}, {len(REFERENCE_COLUMNS)} columns")
print(f"compared  : {len(ALL_FILES)} files")
print()
if SCHEMA_IDENTICAL:
    print("VERDICT   every file carries the same columns in the same order.")
else:
    print(f"VERDICT   {len(column_differences)} file(s) differ from the reference:")
    for d in column_differences:
        print(f"  {d['file']}   ({d['n_columns']} columns)")
        if d["missing"]:
            print(f"      missing : {d['missing']}")
        if d["extra"]:
            print(f"      extra   : {d['extra']}")
        if d["same_columns_reordered"]:
            print("      same columns, different order")
# Out:
# reference : ARP_Spoofing_train.pcap.csv, 45 columns
# compared  : 72 files
#
# VERDICT   every file carries the same columns in the same order.

# %% [markdown]
# Matching column names do not mean matching types. pandas infers a type per file, so the
# same column can come back as int64 in one file and float64 in another purely because one
# of them happens to contain a missing value. That is a property of how the file was read
# rather than of the data, so I check it separately and treat any difference as something
# to look at rather than as a broken schema.

# %%
dtype_files = ALL_FILES if not FAST else ALL_FILES[:FAST_FILE_LIMIT]
REFERENCE_DTYPES = {c: str(t) for c, t in ref.dtypes.items()}
dtype_differences = []

for path in dtype_files:
    for col, t in pd.read_csv(path).dtypes.items():
        reference_type = REFERENCE_DTYPES.get(col)
        if reference_type is not None and str(t) != reference_type:
            dtype_differences.append(
                {"file": path.name, "column": col, "reference": reference_type, "found": str(t)}
            )

print(f"read in full : {len(dtype_files)} of {len(ALL_FILES)} files" + ("   (FAST=1)" if FAST else ""))
print()
if not dtype_differences:
    print("No column changed type between the files read.")
else:
    print(f"{len(dtype_differences)} column/file pairs differ in inferred type:")
    print(pd.DataFrame(dtype_differences).to_string(index=False))
if FAST:
    print()
    print("This covers part of the corpus only. Rerun with FAST=0 before relying on it.")
# Out:
# read in full : 8 of 72 files   (FAST=1)
#
# No column changed type between the files read.
#
# This covers part of the corpus only. Rerun with FAST=0 before relying on it.

# %% [markdown]
# Row counts come next, and they matter more than they look. Parsing seventy-two files
# just to count lines is wasteful, so I count newlines instead, and check that shortcut
# against pandas on the reference file before trusting it anywhere else.

# %%
fast_count, pandas_count = inv.verify_row_count(REFERENCE_FILE)
print(f"newline count vs pandas on {REFERENCE_FILE.name} : {fast_count:,} vs {pandas_count:,}")
if fast_count == pandas_count:
    print("They agree, so newline counting is safe for the remaining files.")
else:
    print("They disagree, which means a field contains a newline. Counts below are wrong.")
print()

files["rows"] = [inv.count_data_rows(p) for p in ALL_FILES]
TOTAL_ROWS = int(files["rows"].sum())

print(files[["file", "split", "family", "rows"]].to_string(index=False))
print()

per_family = (
    files.groupby("family")["rows"]
    .agg(["sum", "count"])
    .rename(columns={"sum": "rows", "count": "files"})
    .sort_values("rows", ascending=False)
)
per_family["share_pct"] = (100 * per_family["rows"] / TOTAL_ROWS).round(2)

print("rows per attack family:")
print(per_family.to_string())
print()
print(f"total rows across {len(ALL_FILES)} files : {TOTAL_ROWS:,}")
largest, smallest = per_family["rows"].iloc[0], per_family["rows"].iloc[-1]
print(
    f"largest family {per_family.index[0]} at {largest:,} rows, "
    f"smallest {per_family.index[-1]} at {smallest:,}, "
    f"a ratio of {largest / max(smallest, 1):,.0f} to 1"
)
print("That ratio is the reason macro-F1 is the primary metric and not accuracy.")
# Out:
# newline count vs pandas on ARP_Spoofing_train.pcap.csv : 16,047 vs 16,047
# They agree, so newline counting is safe for the remaining files.
#
#                                   file split       family   rows
#            ARP_Spoofing_train.pcap.csv train ARP_Spoofing  16047
#                  Benign_train.pcap.csv train       Benign 192732
# MQTT-DDoS-Connect_Flood_train.pcap.csv train         MQTT 173036
# MQTT-DDoS-Publish_Flood_train.pcap.csv train         MQTT  27623
#  MQTT-DoS-Connect_Flood_train.pcap.csv train         MQTT  12773
#  MQTT-DoS-Publish_Flood_train.pcap.csv train         MQTT  44376
#     MQTT-Malformed_Data_train.pcap.csv train         MQTT   5130
#           Recon-OS_Scan_train.pcap.csv train        Recon  16832
#        Recon-Ping_Sweep_train.pcap.csv train        Recon    740
#         Recon-Port_Scan_train.pcap.csv train        Recon  83981
#           Recon-VulScan_train.pcap.csv train        Recon   2173
#       TCP_IP-DDoS-ICMP1_train.pcap.csv train       TCP_IP 194938
#       TCP_IP-DDoS-ICMP2_train.pcap.csv train       TCP_IP 194818
#       TCP_IP-DDoS-ICMP3_train.pcap.csv train       TCP_IP 189710
#       TCP_IP-DDoS-ICMP4_train.pcap.csv train       TCP_IP 192741
#       TCP_IP-DDoS-ICMP5_train.pcap.csv train       TCP_IP 195032
#       TCP_IP-DDoS-ICMP6_train.pcap.csv train       TCP_IP 190875
#       TCP_IP-DDoS-ICMP7_train.pcap.csv train       TCP_IP 186022
#       TCP_IP-DDoS-ICMP8_train.pcap.csv train       TCP_IP 193340
#        TCP_IP-DDoS-SYN1_train.pcap.csv train       TCP_IP 199390
#        TCP_IP-DDoS-SYN2_train.pcap.csv train       TCP_IP 203669
#        TCP_IP-DDoS-SYN3_train.pcap.csv train       TCP_IP 202023
#        TCP_IP-DDoS-SYN4_train.pcap.csv train       TCP_IP 196880
#        TCP_IP-DDoS-TCP1_train.pcap.csv train       TCP_IP 202311
#        TCP_IP-DDoS-TCP2_train.pcap.csv train       TCP_IP 197081
#        TCP_IP-DDoS-TCP3_train.pcap.csv train       TCP_IP 204075
#        TCP_IP-DDoS-TCP4_train.pcap.csv train       TCP_IP 200998
#        TCP_IP-DDoS-UDP1_train.pcap.csv train       TCP_IP 206170
#        TCP_IP-DDoS-UDP2_train.pcap.csv train       TCP_IP 207295
#        TCP_IP-DDoS-UDP3_train.pcap.csv train       TCP_IP 206604
#        TCP_IP-DDoS-UDP4_train.pcap.csv train       TCP_IP 206343
#        TCP_IP-DDoS-UDP5_train.pcap.csv train       TCP_IP 205507
#        TCP_IP-DDoS-UDP6_train.pcap.csv train       TCP_IP 202247
#        TCP_IP-DDoS-UDP7_train.pcap.csv train       TCP_IP 197685
#        TCP_IP-DDoS-UDP8_train.pcap.csv train       TCP_IP 204105
#        TCP_IP-DoS-ICMP1_train.pcap.csv train       TCP_IP 104507
#        TCP_IP-DoS-ICMP2_train.pcap.csv train       TCP_IP  96977
#        TCP_IP-DoS-ICMP3_train.pcap.csv train       TCP_IP 108686
#        TCP_IP-DoS-ICMP4_train.pcap.csv train       TCP_IP 106122
#         TCP_IP-DoS-SYN1_train.pcap.csv train       TCP_IP 111431
#         TCP_IP-DoS-SYN2_train.pcap.csv train       TCP_IP 111647
#         TCP_IP-DoS-SYN3_train.pcap.csv train       TCP_IP 108190
#         TCP_IP-DoS-SYN4_train.pcap.csv train       TCP_IP 110635
#         TCP_IP-DoS-TCP1_train.pcap.csv train       TCP_IP  95407
#         TCP_IP-DoS-TCP2_train.pcap.csv train       TCP_IP  95521
#         TCP_IP-DoS-TCP3_train.pcap.csv train       TCP_IP  95968
#         TCP_IP-DoS-TCP4_train.pcap.csv train       TCP_IP  93488
#         TCP_IP-DoS-UDP1_train.pcap.csv train       TCP_IP 137011
#         TCP_IP-DoS-UDP2_train.pcap.csv train       TCP_IP 140492
#         TCP_IP-DoS-UDP3_train.pcap.csv train       TCP_IP 146146
#         TCP_IP-DoS-UDP4_train.pcap.csv train       TCP_IP 143301
#             ARP_Spoofing_test.pcap.csv  test ARP_Spoofing   1744
#                   Benign_test.pcap.csv  test       Benign  37607
#  MQTT-DDoS-Connect_Flood_test.pcap.csv  test         MQTT  41916
#  MQTT-DDoS-Publish_Flood_test.pcap.csv  test         MQTT   8416
#   MQTT-DoS-Connect_Flood_test.pcap.csv  test         MQTT   3131
#   MQTT-DoS-Publish_Flood_test.pcap.csv  test         MQTT   8505
#      MQTT-Malformed_Data_test.pcap.csv  test         MQTT   1747
#            Recon-OS_Scan_test.pcap.csv  test        Recon   3834
#         Recon-Ping_Sweep_test.pcap.csv  test        Recon    186
#          Recon-Port_Scan_test.pcap.csv  test        Recon  22622
#            Recon-VulScan_test.pcap.csv  test        Recon   1034
#        TCP_IP-DDoS-ICMP1_test.pcap.csv  test       TCP_IP 154007
#        TCP_IP-DDoS-ICMP2_test.pcap.csv  test       TCP_IP 195692
#          TCP_IP-DDoS-SYN_test.pcap.csv  test       TCP_IP 172397
#          TCP_IP-DDoS-TCP_test.pcap.csv  test       TCP_IP 182598
#         TCP_IP-DDoS-UDP1_test.pcap.csv  test       TCP_IP 205654
#         TCP_IP-DDoS-UDP2_test.pcap.csv  test       TCP_IP 156416
#          TCP_IP-DoS-ICMP_test.pcap.csv  test       TCP_IP  98432
#           TCP_IP-DoS-SYN_test.pcap.csv  test       TCP_IP  98595
#           TCP_IP-DoS-TCP_test.pcap.csv  test       TCP_IP  82096
#           TCP_IP-DoS-UDP_test.pcap.csv  test       TCP_IP 137553
#
# rows per attack family:
#                  rows  files  share_pct
# family
# TCP_IP        8068828     50      91.95
# MQTT           326653     10       3.72
# Benign         230339      2       2.62
# Recon          131402      8       1.50
# ARP_Spoofing    17791      2       0.20
#
# total rows across 72 files : 8,775,013
# largest family TCP_IP at 8,068,828 rows, smallest ARP_Spoofing at 17,791, a ratio of 454 to 1
# That ratio is the reason macro-F1 is the primary metric and not accuracy.

# %% [markdown]
# What the rest of the project needs from this notebook is the column list, the types, and
# the two boolean answers. Those go to `data/processed/schema.json` so that no later
# notebook has to re-derive them or, worse, assume them. The search results are written
# alongside, because a bare `false` is not evidence of anything on its own.

# %%
schema_doc = {
    "generated_by": "AG_PRAXIS_NB01_load_inventory.ipynb",
    "generated_on": RUN_DATE,
    "git_sha": GIT_SHA,
    "fast_mode": FAST,
    "reference_file": REFERENCE_FILE.name,
    "n_files": len(ALL_FILES),
    "n_columns": len(REFERENCE_COLUMNS),
    "total_rows": TOTAL_ROWS,
    "has_timestamp": HAS_TIMESTAMP,
    "has_endpoint_identifiers": HAS_ENDPOINTS,
    "schema_identical_across_files": SCHEMA_IDENTICAL,
    "files_differing_from_reference": [d["file"] for d in column_differences],
    "columns": REFERENCE_COLUMNS,
    "dtypes": REFERENCE_DTYPES,
    "timestamp_search": {"keywords": inv.TIME_KEYWORDS, **time_hits},
    "endpoint_search": {"keywords": inv.ENDPOINT_KEYWORDS, **endpoint_hits},
    "rows_per_file": dict(zip(files["file"], files["rows"].astype(int))),
    "rows_per_family": {k: int(v) for k, v in per_family["rows"].items()},
}

SCHEMA_PATH = REPO_ROOT / "data" / "processed" / "schema.json"
SCHEMA_PATH.parent.mkdir(parents=True, exist_ok=True)
SCHEMA_PATH.write_text(json.dumps(schema_doc, indent=2) + "\n")
print(f"wrote {SCHEMA_PATH}")

if ARTIFACTS.exists():
    drive_copy = ARTIFACTS / "NB01" / "schema.json"
    drive_copy.parent.mkdir(parents=True, exist_ok=True)
    drive_copy.write_text(json.dumps(schema_doc, indent=2) + "\n")
    print(f"copied to {drive_copy}")

print()
print(json.dumps({k: v for k, v in schema_doc.items() if k not in ("rows_per_file",)}, indent=2))
# Out:
# wrote /content/repo/data/processed/schema.json
# copied to /content/drive/MyDrive/AG_PRAXIS_artifacts/NB01/schema.json
#
# {
#   "generated_by": "AG_PRAXIS_NB01_load_inventory.ipynb",
#   "generated_on": "2026-08-02",
#   "git_sha": "d3f634b",
#   "fast_mode": true,
#   "reference_file": "ARP_Spoofing_train.pcap.csv",
#   "n_files": 72,
#   "n_columns": 45,
#   "total_rows": 8775013,
#   "has_timestamp": false,
#   "has_endpoint_identifiers": false,
#   "schema_identical_across_files": true,
#   "files_differing_from_reference": [],
#   "columns": [
#     "Header_Length",
#     "Protocol Type",
#     "Duration",
#     "Rate",
#     "Srate",
#     "Drate",
#     "fin_flag_number",
#     "syn_flag_number",
#     "rst_flag_number",
#     "psh_flag_number",
#     "ack_flag_number",
#     "ece_flag_number",
#     "cwr_flag_number",
#     "ack_count",
#     "syn_count",
#     "fin_count",
#     "rst_count",
#     "HTTP",
#     "HTTPS",
#     "DNS",
#     "Telnet",
#     "SMTP",
#     "SSH",
#     "IRC",
#     "TCP",
#     "UDP",
#     "DHCP",
#     "ARP",
#     "ICMP",
#     "IGMP",
#     "IPv",
#     "LLC",
#     "Tot sum",
#     "Min",
#     "Max",
#     "AVG",
#     "Std",
#     "Tot size",
#     "IAT",
#     "Number",
#     "Magnitue",
#     "Radius",
#     "Covariance",
#     "Variance",
#     "Weight"
#   ],
#   "dtypes": {
#     "Header_Length": "float64",
#     "Protocol Type": "float64",
#     "Duration": "float64",
#     "Rate": "float64",
#     "Srate": "float64",
#     "Drate": "float64",
#     "fin_flag_number": "float64",
#     "syn_flag_number": "float64",
#     "rst_flag_number": "float64",
#     "psh_flag_number": "float64",
#     "ack_flag_number": "float64",
#     "ece_flag_number": "float64",
#     "cwr_flag_number": "float64",
#     "ack_count": "float64",
#     "syn_count": "float64",
#     "fin_count": "float64",
#     "rst_count": "float64",
#     "HTTP": "float64",
#     "HTTPS": "float64",
#     "DNS": "float64",
#     "Telnet": "float64",
#     "SMTP": "float64",
#     "SSH": "float64",
#     "IRC": "float64",
#     "TCP": "float64",
#     "UDP": "float64",
#     "DHCP": "float64",
#     "ARP": "float64",
#     "ICMP": "float64",
#     "IGMP": "float64",
#     "IPv": "float64",
#     "LLC": "float64",
#     "Tot sum": "float64",
#     "Min": "float64",
#     "Max": "float64",
#     "AVG": "float64",
#     "Std": "float64",
#     "Tot size": "float64",
#     "IAT": "float64",
#     "Number": "float64",
#     "Magnitue": "float64",
#     "Radius": "float64",
#     "Covariance": "float64",
#     "Variance": "float64",
#     "Weight": "float64"
#   },
#   "timestamp_search": {
#     "keywords": [
#       "time",
#       "timestamp",
#       "ts",
#       "date",
#       "epoch"
#     ],
#     "word_hits": {},
#     "substring_hits": {}
#   },
#   "endpoint_search": {
#     "keywords": [
#       "src",
#       "dst",
#       "ip",
#       "mac",
#       "addr",
#       "source",
#       "destination",
#       "port"
#     ],
#     "word_hits": {},
#     "substring_hits": {
#       "IPv": [
#         "ip"
#       ]
#     }
#   },
#   "rows_per_family": {
#     "TCP_IP": 8068828,
#     "MQTT": 326653,
#     "Benign": 230339,
#     "Recon": 131402,
#     "ARP_Spoofing": 17791
#   }
# }

# %% [markdown]
# The last thing to write is a first grouping of the columns into timing, protocol,
# statistical and other. This is guesswork from spelling and nothing else, so the file
# records itself as a draft and lists every column that matched more than one rule. Rate
# is the obvious problem. It reads as timing to me because it is a per-second quantity,
# but it is computed from a count, and a column like `ack_count` matches both protocol and
# statistical with equal justice. I would rather flag those than quietly decide them.

# %%
assignment = inv.assign_families(REFERENCE_COLUMNS)

for name, cols in assignment["families"].items():
    print(f"{name:<12} {len(cols):>3}")
    for col in cols:
        print(f"             {col}")
print()
print(f"label columns : {assignment['labels'] or 'none found by name'}")
print(f"ambiguous     : {len(assignment['ambiguous'])} column(s) matched more than one rule")
for col, names in assignment["ambiguous"].items():
    print(f"                {col}  ->  {' / '.join(names)}  (assigned to {names[0]})")

families_yaml = inv.render_feature_families_yaml(
    assignment,
    source_file=REFERENCE_FILE.name,
    git_sha=GIT_SHA,
    run_date=RUN_DATE,
)

FAMILIES_PATH = REPO_ROOT / "config" / "feature_families.yaml"
FAMILIES_PATH.write_text(families_yaml)
print()
print(f"wrote {FAMILIES_PATH} as a draft")
print()
print(families_yaml)
# Out:
# timing         5
#              Duration
#              Rate
#              Srate
#              Drate
#              IAT
# protocol      28
#              Header_Length
#              Protocol Type
#              fin_flag_number
#              syn_flag_number
#              rst_flag_number
#              psh_flag_number
#              ack_flag_number
#              ece_flag_number
#              cwr_flag_number
#              ack_count
#              syn_count
#              fin_count
#              rst_count
#              HTTP
#              HTTPS
#              DNS
#              Telnet
#              SMTP
#              SSH
#              IRC
#              TCP
#              UDP
#              DHCP
#              ARP
#              ICMP
#              IGMP
#              IPv
#              LLC
# statistical   12
#              Tot sum
#              Min
#              Max
#              AVG
#              Std
#              Tot size
#              Number
#              Magnitue
#              Radius
#              Covariance
#              Variance
#              Weight
# other          0
#
# label columns : none found by name
# ambiguous     : 12 column(s) matched more than one rule
#                 Header_Length  ->  protocol / statistical  (assigned to protocol)
#                 fin_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 syn_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 rst_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 psh_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 ack_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 ece_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 cwr_flag_number  ->  protocol / statistical  (assigned to protocol)
#                 ack_count  ->  protocol / statistical  (assigned to protocol)
#                 syn_count  ->  protocol / statistical  (assigned to protocol)
#                 fin_count  ->  protocol / statistical  (assigned to protocol)
#                 rst_count  ->  protocol / statistical  (assigned to protocol)
#
# wrote /content/repo/config/feature_families.yaml as a draft
#
# # AG_PRAXIS — feature families (DRAFT, NEEDS MANUAL REVIEW)
# #
# # Written by NB01 from column names alone. No column was inspected for
# # what it actually measures. Anything under `ambiguous` matched more than
# # one rule and was assigned to the first match only.
# #
# # Read every line before any experiment depends on these groupings.
# # Set status: reviewed once that has been done.
#
# status: draft
# review_required: true
# generated_by: AG_PRAXIS_NB01_load_inventory.ipynb
# generated_from: ARP_Spoofing_train.pcap.csv
# git_sha: d3f634b
# generated_on: '2026-08-02'
# label_columns: []
# families:
#   timing:
#   - Duration
#   - Rate
#   - Srate
#   - Drate
#   - IAT
#   protocol:
#   - Header_Length
#   - Protocol Type
#   - fin_flag_number
#   - syn_flag_number
#   - rst_flag_number
#   - psh_flag_number
#   - ack_flag_number
#   - ece_flag_number
#   - cwr_flag_number
#   - ack_count
#   - syn_count
#   - fin_count
#   - rst_count
#   - HTTP
#   - HTTPS
#   - DNS
#   - Telnet
#   - SMTP
#   - SSH
#   - IRC
#   - TCP
#   - UDP
#   - DHCP
#   - ARP
#   - ICMP
#   - IGMP
#   - IPv
#   - LLC
#   statistical:
#   - Tot sum
#   - Min
#   - Max
#   - AVG
#   - Std
#   - Tot size
#   - Number
#   - Magnitue
#   - Radius
#   - Covariance
#   - Variance
#   - Weight
#   other: []
# ambiguous:
#   Header_Length:
#   - protocol
#   - statistical
#   fin_flag_number:
#   - protocol
#   - statistical
#   syn_flag_number:
#   - protocol
#   - statistical
#   rst_flag_number:
#   - protocol
#   - statistical
#   psh_flag_number:
#   - protocol
#   - statistical
#   ack_flag_number:
#   - protocol
#   - statistical
#   ece_flag_number:
#   - protocol
#   - statistical
#   cwr_flag_number:
#   - protocol
#   - statistical
#   ack_count:
#   - protocol
#   - statistical
#   syn_count:
#   - protocol
#   - statistical
#   fin_count:
#   - protocol
#   - statistical
#   rst_count:
#   - protocol
#   - statistical

# %% [markdown]
# The entry for `RESULTS_LEDGER.md`, ready to paste.

# %%
status = "reference run" if not FAST else "EXPLORATORY, FAST=1, do not enter in the ledger"

ledger = f"""
### NB01 — data inventory ({RUN_DATE})

| field | value |
|---|---|
| notebook | AG_PRAXIS_NB01_load_inventory.ipynb |
| run date | {RUN_DATE} |
| git sha | {GIT_SHA}{" (working tree dirty)" if GIT_DIRTY else ""} |
| seed | {SEED} |
| FAST | {int(FAST)} |
| status | {status} |
| files read | {len(ALL_FILES)} of {EXPECTED_FILES} expected |
| columns | {len(REFERENCE_COLUMNS)} |
| total rows | {TOTAL_ROWS:,} |
| families | {files['family'].nunique()} |
| classes | {files['class'].nunique()} |
| timestamp column | {"yes" if HAS_TIMESTAMP else "no"} |
| endpoint identifiers | {"yes" if HAS_ENDPOINTS else "no"} |
| schema identical across files | {"yes" if SCHEMA_IDENTICAL else f"no, {len(column_differences)} file(s) differ"} |
| dtype differences | {len(dtype_differences)} across {len(dtype_files)} files read in full |
| metrics | none, no model trained |
| artefacts | data/processed/schema.json, config/feature_families.yaml (draft) |

Ordering available for sequences: {"timestamp" if HAS_TIMESTAMP else "row order within a file only"}.
Grouping available for sequences: {"endpoint identifiers present" if HAS_ENDPOINTS else "none, windows cannot cross a file boundary"}.
"""

print(ledger)
# Out:
# ### NB01 — data inventory (2026-08-02)
#
# | field | value |
# |---|---|
# | notebook | AG_PRAXIS_NB01_load_inventory.ipynb |
# | run date | 2026-08-02 |
# | git sha | d3f634b |
# | seed | 42 |
# | FAST | 1 |
# | status | EXPLORATORY, FAST=1, do not enter in the ledger |
# | files read | 72 of 72 expected |
# | columns | 45 |
# | total rows | 8,775,013 |
# | families | 5 |
# | classes | 57 |
# | timestamp column | no |
# | endpoint identifiers | no |
# | schema identical across files | yes |
# | dtype differences | 0 across 8 files read in full |
# | metrics | none, no model trained |
# | artefacts | data/processed/schema.json, config/feature_families.yaml (draft) |
#
# Ordering available for sequences: row order within a file only.
# Grouping available for sequences: none, windows cannot cross a file boundary.

# %%
import json
s = json.load(open('/content/repo/data/processed/schema.json'))
print(s.get('classes', 'key not found'))
# Out:
# key not found

# %%
import json
s = json.load(open('/content/repo/data/processed/schema.json'))
print(list(s.keys()))
# Out:
# ['generated_by', 'generated_on', 'git_sha', 'fast_mode', 'reference_file', 'n_files', 'n_columns', 'total_rows', 'has_timestamp', 'has_endpoint_identifiers', 'schema_identical_across_files', 'files_differing_from_reference', 'columns', 'dtypes', 'timestamp_search', 'endpoint_search', 'rows_per_file', 'rows_per_family']

# %%
import glob, os
from collections import Counter

files = glob.glob('/content/drive/MyDrive/AG_PRAXIS_data/csv/train/*.csv') + \
        glob.glob('/content/drive/MyDrive/AG_PRAXIS_data/csv/test/*.csv')

names = sorted({os.path.basename(f) for f in files})
print(f"{len(names)} files\n")
for n in names:
    print(" ", n)
# Out:
# 72 files
#
#   ARP_Spoofing_test.pcap.csv
#   ARP_Spoofing_train.pcap.csv
#   Benign_test.pcap.csv
#   Benign_train.pcap.csv
#   MQTT-DDoS-Connect_Flood_test.pcap.csv
#   MQTT-DDoS-Connect_Flood_train.pcap.csv
#   MQTT-DDoS-Publish_Flood_test.pcap.csv
#   MQTT-DDoS-Publish_Flood_train.pcap.csv
#   MQTT-DoS-Connect_Flood_test.pcap.csv
#   MQTT-DoS-Connect_Flood_train.pcap.csv
#   MQTT-DoS-Publish_Flood_test.pcap.csv
#   MQTT-DoS-Publish_Flood_train.pcap.csv
#   MQTT-Malformed_Data_test.pcap.csv
#   MQTT-Malformed_Data_train.pcap.csv
#   Recon-OS_Scan_test.pcap.csv
#   Recon-OS_Scan_train.pcap.csv
#   Recon-Ping_Sweep_test.pcap.csv
#   Recon-Ping_Sweep_train.pcap.csv
#   Recon-Port_Scan_test.pcap.csv
#   Recon-Port_Scan_train.pcap.csv
#   Recon-VulScan_test.pcap.csv
#   Recon-VulScan_train.pcap.csv
#   TCP_IP-DDoS-ICMP1_test.pcap.csv
#   TCP_IP-DDoS-ICMP1_train.pcap.csv
#   TCP_IP-DDoS-ICMP2_test.pcap.csv
#   TCP_IP-DDoS-ICMP2_train.pcap.csv
#   TCP_IP-DDoS-ICMP3_train.pcap.csv
#   TCP_IP-DDoS-ICMP4_train.pcap.csv
#   TCP_IP-DDoS-ICMP5_train.pcap.csv
#   TCP_IP-DDoS-ICMP6_train.pcap.csv
#   TCP_IP-DDoS-ICMP7_train.pcap.csv
#   TCP_IP-DDoS-ICMP8_train.pcap.csv
#   TCP_IP-DDoS-SYN1_train.pcap.csv
#   TCP_IP-DDoS-SYN2_train.pcap.csv
#   TCP_IP-DDoS-SYN3_train.pcap.csv
#   TCP_IP-DDoS-SYN4_train.pcap.csv
#   TCP_IP-DDoS-SYN_test.pcap.csv
#   TCP_IP-DDoS-TCP1_train.pcap.csv
#   TCP_IP-DDoS-TCP2_train.pcap.csv
#   TCP_IP-DDoS-TCP3_train.pcap.csv
#   TCP_IP-DDoS-TCP4_train.pcap.csv
#   TCP_IP-DDoS-TCP_test.pcap.csv
#   TCP_IP-DDoS-UDP1_test.pcap.csv
#   TCP_IP-DDoS-UDP1_train.pcap.csv
#   TCP_IP-DDoS-UDP2_test.pcap.csv
#   TCP_IP-DDoS-UDP2_train.pcap.csv
#   TCP_IP-DDoS-UDP3_train.pcap.csv
#   TCP_IP-DDoS-UDP4_train.pcap.csv
#   TCP_IP-DDoS-UDP5_train.pcap.csv
#   TCP_IP-DDoS-UDP6_train.pcap.csv
#   TCP_IP-DDoS-UDP7_train.pcap.csv
#   TCP_IP-DDoS-UDP8_train.pcap.csv
#   TCP_IP-DoS-ICMP1_train.pcap.csv
#   TCP_IP-DoS-ICMP2_train.pcap.csv
#   TCP_IP-DoS-ICMP3_train.pcap.csv
#   TCP_IP-DoS-ICMP4_train.pcap.csv
#   TCP_IP-DoS-ICMP_test.pcap.csv
#   TCP_IP-DoS-SYN1_train.pcap.csv
#   TCP_IP-DoS-SYN2_train.pcap.csv
#   TCP_IP-DoS-SYN3_train.pcap.csv
#   TCP_IP-DoS-SYN4_train.pcap.csv
#   TCP_IP-DoS-SYN_test.pcap.csv
#   TCP_IP-DoS-TCP1_train.pcap.csv
#   TCP_IP-DoS-TCP2_train.pcap.csv
#   TCP_IP-DoS-TCP3_train.pcap.csv
#   TCP_IP-DoS-TCP4_train.pcap.csv
#   TCP_IP-DoS-TCP_test.pcap.csv
#   TCP_IP-DoS-UDP1_train.pcap.csv
#   TCP_IP-DoS-UDP2_train.pcap.csv
#   TCP_IP-DoS-UDP3_train.pcap.csv
#   TCP_IP-DoS-UDP4_train.pcap.csv
#   TCP_IP-DoS-UDP_test.pcap.csv

# %%
import re, os

def parse_capture(filename):
    n = os.path.basename(filename).replace('.pcap.csv', '')
    partition = 'test' if n.endswith('_test') else 'train'
    n = re.sub(r'_(train|test)$', '', n)
    capture_id = n                          # e.g. TCP_IP-DDoS-ICMP1
    label = re.sub(r'\d+$', '', n)          # strip chunk number
    label = label.replace('TCP_IP-', '')
    if label == 'ARP_Spoofing':
        label = 'Spoofing'
    return {'capture_id': capture_id, 'label': label, 'partition': partition}

# %%
import re, os, glob
from collections import defaultdict

files = glob.glob('/content/drive/MyDrive/AG_PRAXIS_data/csv/*/*.csv')
caps = defaultdict(lambda: {'train': set(), 'test': set()})

for f in files:
    n = os.path.basename(f).replace('.pcap.csv', '')
    part = 'test' if n.endswith('_test') else 'train'
    n = re.sub(r'_(train|test)$', '', n)
    lab = re.sub(r'\d+$', '', n).replace('TCP_IP-', '')
    if lab == 'ARP_Spoofing': lab = 'Spoofing'
    caps[lab][part].add(n)

print(f"{'class':<28} {'train caps':>10} {'test caps':>10}")
print('-'*50)
for k in sorted(caps):
    print(f"{k:<28} {len(caps[k]['train']):>10} {len(caps[k]['test']):>10}")
print(f"\n{len(caps)} classes")
# Out:
# class                        train caps  test caps
# --------------------------------------------------
# Benign                                1          1
# DDoS-ICMP                             8          2
# DDoS-SYN                              4          1
# DDoS-TCP                              4          1
# DDoS-UDP                              8          2
# DoS-ICMP                              4          1
# DoS-SYN                               4          1
# DoS-TCP                               4          1
# DoS-UDP                               4          1
# MQTT-DDoS-Connect_Flood               1          1
# MQTT-DDoS-Publish_Flood               1          1
# MQTT-DoS-Connect_Flood                1          1
# MQTT-DoS-Publish_Flood                1          1
# MQTT-Malformed_Data                   1          1
# Recon-OS_Scan                         1          1
# Recon-Ping_Sweep                      1          1
# Recon-Port_Scan                       1          1
# Recon-VulScan                         1          1
# Spoofing                              1          1
#
# 19 classes
